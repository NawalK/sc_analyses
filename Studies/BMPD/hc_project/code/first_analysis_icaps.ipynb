# %% [markdown]
# # BMPD HC project
# ## Spinal cord only - Consensus clustering

# %%
import sys

sys.path.append('/media/miplab-nas2/Data3/Nawal/Tools/iCAPs/')
from icap_consensus_clustering import ConsensusClustering
from icap_analyses import iCAPs

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nibabel as nib
import os.path
import json
import nibabel as nib

# Set numpy to print only 2 decimal digits for neatness
np.set_printoptions(precision=2, suppress=True)

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
with open('../config/hc_project_icaps_spinalcord.json') as config_file:
    config_hc_project = json.load(config_file)

# %%
icaps_hc_project = iCAPs(config_hc_project,10)

# %%
icaps_hc_project.plot(lthresh=2,uthresh=4,colormap='autumn',save_results=True,show_spinal_levels=True)
