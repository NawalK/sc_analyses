# %% [markdown]
# # Static FC analyses Stroke & Elderly

# %%
import sys

sys.path.append('/media/miplab-nas2/Data3/Nawal/Tools/StaticFC/')
sys.path.append('/media/miplab-nas2/Data3/Nawal/Tools/Clinical/')
from static_fc import StaticFC
from clinical_analyses import ClinicalAnalyses

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nibabel as nib
import os.path
import json

# Set numpy to print only 2 decimal digits for neatness
np.set_printoptions(precision=2, suppress=True)

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/kinany/anaconda3/lib/python3.9/site-packages/outdated/utils.py:14: OutdatedCacheFailedWarning: Failed to use cache while checking for outdated package.
# Set the environment variable OUTDATED_RAISE_EXCEPTION=1 for a full traceback.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %% [markdown]
# ## 0. Load configuration & patient data

# %%
with open('../config/sFC_config_age_stroke_young.json') as config_file:
    config = json.load(config_file)

# %%
patients = ClinicalAnalyses(config)
# Out:
# Creating instance for config age_stroke_young_C5toC7
# overwrite_clinical: True

# %%
clinical_info = patients.get_patient_info()
# Out:
# Extracting clinical data...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 clinical_info = patients.get_patient_info()
#
# File /media/miplab-nas2/Data3/Nawal/Tools/Clinical/clinical_analyses.py:101, in ClinicalAnalyses.get_patient_info(self)
#      98             gender.append(raw_clinical_data.loc[raw_clinical_data.iloc[:,1]==sub, raw_clinical_data.columns[19]].values[0])
#     100     colnames = ["sub", "sess", "CST_L", "CST_R", "CST","vol", "fm", "pinch", "mas", "age", "gender"]
# --> 101     clinical_infos = pd.DataFrame(list(zip(subs, sessions, weighted_load_L, weighted_load_R, weighted_load, lesion_vol, fm, pinch, mas, age, gender)), columns=colnames)
#     102     clinical_infos.to_pickle(self.config['output_dir'] + 'clinical_infos_' + self.config['tag_results'] + '.pkl')  # Save dataframe
#     104 else:
#
# UnboundLocalError: local variable 'weighted_load' referenced before assignment

# %%
patients.plot_info(clinical_info,['fm','mas','pinch','CST','vol'])

# %% [markdown]
# ## 1. Prepare FC data

# %% [markdown]
# #### 1a. Create instance of StaticFC class for further analyses

# %%
sFC = StaticFC(config)
# Out:
# Creating instance for config age_stroke_young_C5toC7_gm
# overwrite_denoising: False
# overwrite_flipping: False
# overwrite_smoothing: False
# overwrite_tc: False
# overwrite_corr: True
# overwrite_alff_maps: False
# overwrite_alff_rois: True

# %% [markdown]
# #### 1b. Prepare data
# *_Denoise (filter or not) > Normalize to PAM50 > Flip if neeeded > Smooth_*

# %%
sFC.prepare_data()
# Out:
# PREPARE DATA
# ... Denoising
# Overwrite old files: True
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   1 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=5)]: Done   1 out of   1 | elapsed:   37.1s finished
# ... Operation performed in 37.105 s
# ... Normalize denoised images
# Overwrite old files: True
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
#
# --
# Spinal Cord Toolbox (5.6)
#
# sct_apply_transfo -i /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/Young/RS_AS/func//RS_AS_fmri_moco_denoised_bp.nii.gz -d /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/PAM50_Age_Stroke/template/PAM50_t2.nii.gz -w /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/Young/RS_AS/func//Normalization/warp_fmri2template.nii.gz -x spline -o /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/Young/RS_AS/func//RS_AS_fmri_moco_denoised_bp_pam50.nii.gz
# --
#
#
# Parse list of warping fields...
#
# Get dimensions of data...
#   144 x 48 x 27 x 240
#
# Copying input data to tmp folder and convert to nii...
# cp /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/PAM50_Age_Stroke/template/PAM50_t2.nii.gz /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj/PAM50_t2.nii.gz
# cp /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/Young/RS_AS/func//Normalization/warp_fmri2template.nii.gz /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj/warp_fmri2template.nii.gz
#
# Split along T dimension...
#
# Apply transformation to each 3D volume...
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0000.nii -o data_reg_T0000.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0001.nii -o data_reg_T0001.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0002.nii -o data_reg_T0002.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0003.nii -o data_reg_T0003.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0004.nii -o data_reg_T0004.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0005.nii -o data_reg_T0005.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0006.nii -o data_reg_T0006.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0007.nii -o data_reg_T0007.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0008.nii -o data_reg_T0008.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0009.nii -o data_reg_T0009.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0010.nii -o data_reg_T0010.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0011.nii -o data_reg_T0011.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0012.nii -o data_reg_T0012.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0013.nii -o data_reg_T0013.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0014.nii -o data_reg_T0014.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0015.nii -o data_reg_T0015.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0016.nii -o data_reg_T0016.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0017.nii -o data_reg_T0017.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0018.nii -o data_reg_T0018.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0019.nii -o data_reg_T0019.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0020.nii -o data_reg_T0020.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0021.nii -o data_reg_T0021.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0022.nii -o data_reg_T0022.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0023.nii -o data_reg_T0023.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0024.nii -o data_reg_T0024.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0025.nii -o data_reg_T0025.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0026.nii -o data_reg_T0026.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0027.nii -o data_reg_T0027.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0028.nii -o data_reg_T0028.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0029.nii -o data_reg_T0029.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0030.nii -o data_reg_T0030.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0031.nii -o data_reg_T0031.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0032.nii -o data_reg_T0032.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0033.nii -o data_reg_T0033.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0034.nii -o data_reg_T0034.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0035.nii -o data_reg_T0035.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0036.nii -o data_reg_T0036.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0037.nii -o data_reg_T0037.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0038.nii -o data_reg_T0038.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0039.nii -o data_reg_T0039.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0040.nii -o data_reg_T0040.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0041.nii -o data_reg_T0041.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0042.nii -o data_reg_T0042.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0043.nii -o data_reg_T0043.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0044.nii -o data_reg_T0044.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0045.nii -o data_reg_T0045.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0046.nii -o data_reg_T0046.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0047.nii -o data_reg_T0047.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0048.nii -o data_reg_T0048.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0049.nii -o data_reg_T0049.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0050.nii -o data_reg_T0050.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0051.nii -o data_reg_T0051.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0052.nii -o data_reg_T0052.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0053.nii -o data_reg_T0053.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0054.nii -o data_reg_T0054.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0055.nii -o data_reg_T0055.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0056.nii -o data_reg_T0056.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0057.nii -o data_reg_T0057.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0058.nii -o data_reg_T0058.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0059.nii -o data_reg_T0059.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0060.nii -o data_reg_T0060.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0061.nii -o data_reg_T0061.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0062.nii -o data_reg_T0062.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0063.nii -o data_reg_T0063.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0064.nii -o data_reg_T0064.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0065.nii -o data_reg_T0065.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0066.nii -o data_reg_T0066.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0067.nii -o data_reg_T0067.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0068.nii -o data_reg_T0068.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0069.nii -o data_reg_T0069.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0070.nii -o data_reg_T0070.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0071.nii -o data_reg_T0071.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0072.nii -o data_reg_T0072.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0073.nii -o data_reg_T0073.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0074.nii -o data_reg_T0074.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0075.nii -o data_reg_T0075.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0076.nii -o data_reg_T0076.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0077.nii -o data_reg_T0077.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0078.nii -o data_reg_T0078.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0079.nii -o data_reg_T0079.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0080.nii -o data_reg_T0080.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0081.nii -o data_reg_T0081.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0082.nii -o data_reg_T0082.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0083.nii -o data_reg_T0083.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0084.nii -o data_reg_T0084.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0085.nii -o data_reg_T0085.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0086.nii -o data_reg_T0086.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0087.nii -o data_reg_T0087.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0088.nii -o data_reg_T0088.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0089.nii -o data_reg_T0089.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0090.nii -o data_reg_T0090.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0091.nii -o data_reg_T0091.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0092.nii -o data_reg_T0092.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0093.nii -o data_reg_T0093.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0094.nii -o data_reg_T0094.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0095.nii -o data_reg_T0095.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0096.nii -o data_reg_T0096.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0097.nii -o data_reg_T0097.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0098.nii -o data_reg_T0098.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0099.nii -o data_reg_T0099.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0100.nii -o data_reg_T0100.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0101.nii -o data_reg_T0101.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0102.nii -o data_reg_T0102.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0103.nii -o data_reg_T0103.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0104.nii -o data_reg_T0104.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0105.nii -o data_reg_T0105.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0106.nii -o data_reg_T0106.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0107.nii -o data_reg_T0107.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0108.nii -o data_reg_T0108.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0109.nii -o data_reg_T0109.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0110.nii -o data_reg_T0110.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0111.nii -o data_reg_T0111.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0112.nii -o data_reg_T0112.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0113.nii -o data_reg_T0113.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0114.nii -o data_reg_T0114.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0115.nii -o data_reg_T0115.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0116.nii -o data_reg_T0116.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0117.nii -o data_reg_T0117.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0118.nii -o data_reg_T0118.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0119.nii -o data_reg_T0119.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0120.nii -o data_reg_T0120.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0121.nii -o data_reg_T0121.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0122.nii -o data_reg_T0122.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0123.nii -o data_reg_T0123.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0124.nii -o data_reg_T0124.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0125.nii -o data_reg_T0125.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0126.nii -o data_reg_T0126.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0127.nii -o data_reg_T0127.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0128.nii -o data_reg_T0128.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0129.nii -o data_reg_T0129.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0130.nii -o data_reg_T0130.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0131.nii -o data_reg_T0131.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0132.nii -o data_reg_T0132.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0133.nii -o data_reg_T0133.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0134.nii -o data_reg_T0134.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0135.nii -o data_reg_T0135.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0136.nii -o data_reg_T0136.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0137.nii -o data_reg_T0137.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0138.nii -o data_reg_T0138.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0139.nii -o data_reg_T0139.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0140.nii -o data_reg_T0140.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0141.nii -o data_reg_T0141.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0142.nii -o data_reg_T0142.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0143.nii -o data_reg_T0143.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0144.nii -o data_reg_T0144.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0145.nii -o data_reg_T0145.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0146.nii -o data_reg_T0146.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0147.nii -o data_reg_T0147.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0148.nii -o data_reg_T0148.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0149.nii -o data_reg_T0149.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0150.nii -o data_reg_T0150.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0151.nii -o data_reg_T0151.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0152.nii -o data_reg_T0152.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0153.nii -o data_reg_T0153.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0154.nii -o data_reg_T0154.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0155.nii -o data_reg_T0155.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0156.nii -o data_reg_T0156.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0157.nii -o data_reg_T0157.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0158.nii -o data_reg_T0158.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0159.nii -o data_reg_T0159.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0160.nii -o data_reg_T0160.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0161.nii -o data_reg_T0161.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0162.nii -o data_reg_T0162.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0163.nii -o data_reg_T0163.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0164.nii -o data_reg_T0164.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0165.nii -o data_reg_T0165.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0166.nii -o data_reg_T0166.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0167.nii -o data_reg_T0167.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0168.nii -o data_reg_T0168.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0169.nii -o data_reg_T0169.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0170.nii -o data_reg_T0170.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0171.nii -o data_reg_T0171.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0172.nii -o data_reg_T0172.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0173.nii -o data_reg_T0173.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0174.nii -o data_reg_T0174.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0175.nii -o data_reg_T0175.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0176.nii -o data_reg_T0176.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0177.nii -o data_reg_T0177.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0178.nii -o data_reg_T0178.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0179.nii -o data_reg_T0179.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0180.nii -o data_reg_T0180.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0181.nii -o data_reg_T0181.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0182.nii -o data_reg_T0182.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0183.nii -o data_reg_T0183.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0184.nii -o data_reg_T0184.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0185.nii -o data_reg_T0185.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0186.nii -o data_reg_T0186.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0187.nii -o data_reg_T0187.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0188.nii -o data_reg_T0188.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0189.nii -o data_reg_T0189.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0190.nii -o data_reg_T0190.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0191.nii -o data_reg_T0191.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0192.nii -o data_reg_T0192.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0193.nii -o data_reg_T0193.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0194.nii -o data_reg_T0194.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0195.nii -o data_reg_T0195.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0196.nii -o data_reg_T0196.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0197.nii -o data_reg_T0197.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0198.nii -o data_reg_T0198.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0199.nii -o data_reg_T0199.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0200.nii -o data_reg_T0200.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0201.nii -o data_reg_T0201.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0202.nii -o data_reg_T0202.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0203.nii -o data_reg_T0203.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0204.nii -o data_reg_T0204.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0205.nii -o data_reg_T0205.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0206.nii -o data_reg_T0206.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0207.nii -o data_reg_T0207.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0208.nii -o data_reg_T0208.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0209.nii -o data_reg_T0209.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0210.nii -o data_reg_T0210.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0211.nii -o data_reg_T0211.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0212.nii -o data_reg_T0212.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127124308.992398-apply_transfo-8yfo6usj
# ...
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0175.nii -o data_reg_T0175.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0176.nii -o data_reg_T0176.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0177.nii -o data_reg_T0177.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0178.nii -o data_reg_T0178.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0179.nii -o data_reg_T0179.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0180.nii -o data_reg_T0180.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0181.nii -o data_reg_T0181.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0182.nii -o data_reg_T0182.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0183.nii -o data_reg_T0183.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0184.nii -o data_reg_T0184.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0185.nii -o data_reg_T0185.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0186.nii -o data_reg_T0186.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0187.nii -o data_reg_T0187.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0188.nii -o data_reg_T0188.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0189.nii -o data_reg_T0189.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0190.nii -o data_reg_T0190.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0191.nii -o data_reg_T0191.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0192.nii -o data_reg_T0192.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0193.nii -o data_reg_T0193.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0194.nii -o data_reg_T0194.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0195.nii -o data_reg_T0195.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0196.nii -o data_reg_T0196.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0197.nii -o data_reg_T0197.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0198.nii -o data_reg_T0198.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0199.nii -o data_reg_T0199.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0200.nii -o data_reg_T0200.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0201.nii -o data_reg_T0201.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0202.nii -o data_reg_T0202.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0203.nii -o data_reg_T0203.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0204.nii -o data_reg_T0204.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0205.nii -o data_reg_T0205.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0206.nii -o data_reg_T0206.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0207.nii -o data_reg_T0207.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0208.nii -o data_reg_T0208.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0209.nii -o data_reg_T0209.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0210.nii -o data_reg_T0210.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0211.nii -o data_reg_T0211.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0212.nii -o data_reg_T0212.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0213.nii -o data_reg_T0213.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0214.nii -o data_reg_T0214.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0215.nii -o data_reg_T0215.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0216.nii -o data_reg_T0216.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0217.nii -o data_reg_T0217.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0218.nii -o data_reg_T0218.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0219.nii -o data_reg_T0219.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0220.nii -o data_reg_T0220.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0221.nii -o data_reg_T0221.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0222.nii -o data_reg_T0222.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0223.nii -o data_reg_T0223.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0224.nii -o data_reg_T0224.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0225.nii -o data_reg_T0225.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0226.nii -o data_reg_T0226.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0227.nii -o data_reg_T0227.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0228.nii -o data_reg_T0228.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0229.nii -o data_reg_T0229.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0230.nii -o data_reg_T0230.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0231.nii -o data_reg_T0231.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0232.nii -o data_reg_T0232.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0233.nii -o data_reg_T0233.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0234.nii -o data_reg_T0234.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0235.nii -o data_reg_T0235.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0236.nii -o data_reg_T0236.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0237.nii -o data_reg_T0237.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0238.nii -o data_reg_T0238.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# /home/kinany/sct_5.6/bin/isct_antsApplyTransforms -d 3 -i data_T0239.nii -o data_reg_T0239.nii -t warp_fmri2template.nii.gz -r PAM50_t2.nii.gz -n 'BSpline[3]' # in /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
#
# Merge file back...
# File /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/Young/RS_AS/func/RS_AS_fmri_moco_denoised_nofilter_pam50.nii.gz already exists. Deleting it..
#
# Remove temporary files...
# rm -rf /tmp/sct-20231127125853.088108-apply_transfo-znhmicnj
# Copy affine matrix from destination space to make sure qform/sform are the same.
#
# Done! To view results, run one of the following commands (depending on your preferred viewer):
# fsleyes /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/PAM50_Age_Stroke/template/PAM50_t2.nii.gz /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/Young/RS_AS/func//RS_AS_fmri_moco_denoised_nofilter_pam50.nii.gz &
#
# fslview_deprecated /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/PAM50_Age_Stroke/template/PAM50_t2.nii.gz /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/Young/RS_AS/func//RS_AS_fmri_moco_denoised_nofilter_pam50.nii.gz &
#
# fslview /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/PAM50_Age_Stroke/template/PAM50_t2.nii.gz /media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/Young/RS_AS/func//RS_AS_fmri_moco_denoised_nofilter_pam50.nii.gz &
#
# [Parallel(n_jobs=5)]: Done   1 tasks      | elapsed: 31.3min
# [Parallel(n_jobs=5)]: Done   1 out of   1 | elapsed: 31.3min finished
# ... Operation performed in 1877.304 s
# ... Flip normalized denoised images
# Overwrite old files: False
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   0 out of   0 | elapsed:    0.0s finished
# ... Operation performed in 0.003 s
# ... Smooth normalized denoised images
# Overwrite old files: True
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   1 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=5)]: Done   1 out of   1 | elapsed: 11.9min finished
# ... Operation performed in 715.880 s
# ...DONE!

# %% [markdown]
# ####  1c. Load timecourses

# %%
tcs = sFC.extract_tcs()
# Out:
# Timecourses extraction
# Overwrite old files: False
# Extracting timecourses for subject SUVA-TIMES-002
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-003
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-006
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-007
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-008
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-010
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-014
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-021
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-022
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-023
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-025
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-026
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-028
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject SUVA-TIMES-031
# ...Session T3
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject sub-001
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject sub-002
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject sub-004
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject sub-005
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject sub-007
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject sub-009
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject sub-011
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject sub-012
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_AT
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_EP
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_FB
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_GB
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_GP
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_LJ
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_MD
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_MP
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_NG
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_NK
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_RL
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_SA
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_SL
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_SW
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_VG
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_VS
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_YF
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_AO
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR
# Extracting timecourses for subject RS_AS
# ...Session
# ......In frost_C5toC7_gm_VL
# ......In frost_C5toC7_gm_VR
# ......In frost_C5toC7_gm_DL
# ......In frost_C5toC7_gm_DR

# %% [markdown]
# ### 2. Correlations analyses

# %% [markdown]
# #### 2a. Computations

# %%
corrs_df,corrs_stats_df = sFC.compute_correlations(tcs=tcs)
# Out:
# ROI-TO-ROI CORRELATION
# Overwrite old files: True
# ...Compute correlations
# /media/miplab-nas2/Data3/Nawal/Tools/StaticFC/static_fc.py:255: RuntimeWarning: divide by zero encountered in arctanh
#   rhos_Z.append(np.arctanh(np.corrcoef(tcs.loc[(tcs['sub']==sub) & (tcs['sess']==sess) & (tcs['roi']==roi1),'tc'].values, tcs.loc[(tcs['sub']==sub) & (tcs['sess']==sess) & (tcs['roi']==roi2),'tc'].values)[1,0]))
# ...Compute statistical significance

# %%
sFC.compare_correlations(corrs_df, ['P','Y'], paired=False)
# Out:
# COMPARE FC PATTERNS BETWEEN GROUPS
# Group 1: P
# Group 2: Y
# (                  roi1                roi2         p
#  0   frost_C5toC7_gm_VL  frost_C5toC7_gm_VL  0.257568
#  1   frost_C5toC7_gm_VL  frost_C5toC7_gm_VR  0.898552
#  2   frost_C5toC7_gm_VL  frost_C5toC7_gm_DL  0.372160
#  3   frost_C5toC7_gm_VL  frost_C5toC7_gm_DR  0.547822
#  4   frost_C5toC7_gm_VR  frost_C5toC7_gm_VL  0.898552
#  5   frost_C5toC7_gm_VR  frost_C5toC7_gm_VR  0.772406
#  6   frost_C5toC7_gm_VR  frost_C5toC7_gm_DL  0.391993
#  7   frost_C5toC7_gm_VR  frost_C5toC7_gm_DR  0.025078
#  8   frost_C5toC7_gm_DL  frost_C5toC7_gm_VL  0.372160
#  9   frost_C5toC7_gm_DL  frost_C5toC7_gm_VR  0.391993
#  10  frost_C5toC7_gm_DL  frost_C5toC7_gm_DL  0.262688
#  11  frost_C5toC7_gm_DL  frost_C5toC7_gm_DR  0.251210
#  12  frost_C5toC7_gm_DR  frost_C5toC7_gm_VL  0.547822
#  13  frost_C5toC7_gm_DR  frost_C5toC7_gm_VR  0.025078
#  14  frost_C5toC7_gm_DR  frost_C5toC7_gm_DL  0.251210
#  15  frost_C5toC7_gm_DR  frost_C5toC7_gm_DR  0.814603,
#  array([[  nan, -0.  , -0.03,  0.03],
#         [-0.  ,   nan,  0.03,  0.09],
#         [-0.03,  0.03,   nan, -0.06],
#         [ 0.03,  0.09, -0.06,   nan]]))

# %%
corrs_df
# Out:
#                sub sess               roi1               roi2      rho_Z
# 0   SUVA-TIMES-002   T3  iCAP_C5toC7_CST_L  iCAP_C5toC7_CST_L  18.368400
# 1   SUVA-TIMES-002   T3  iCAP_C5toC7_CST_L  iCAP_C5toC7_CST_R   0.093489
# 2   SUVA-TIMES-002   T3  iCAP_C5toC7_CST_R  iCAP_C5toC7_CST_L   0.093489
# 3   SUVA-TIMES-002   T3  iCAP_C5toC7_CST_R  iCAP_C5toC7_CST_R        inf
# 4   SUVA-TIMES-003   T3  iCAP_C5toC7_CST_L  iCAP_C5toC7_CST_L        inf
# ..             ...  ...                ...                ...        ...
# 79         sub-009       iCAP_C5toC7_CST_R  iCAP_C5toC7_CST_R        inf
# 80         sub-011       iCAP_C5toC7_CST_L  iCAP_C5toC7_CST_L        inf
# 81         sub-011       iCAP_C5toC7_CST_L  iCAP_C5toC7_CST_R   0.083622
# 82         sub-011       iCAP_C5toC7_CST_R  iCAP_C5toC7_CST_L   0.083622
# 83         sub-011       iCAP_C5toC7_CST_R  iCAP_C5toC7_CST_R        inf
#
# [84 rows x 5 columns]

# %% [markdown]
# #### 2b. Link with functional connectivity
# _Note: for the next steps, select corrs_totest(_names) based on config & chosen analyses_

# %% [markdown]
# #### Option 1: Interhemispheric FC

# %% [markdown]
# _**If using whole cord**_

# %%
vv = [corrs_df[(corrs_df['sess']=='T3') & (corrs_df['roi1']=='iCAP_C5toC7_gm_VR') & (corrs_df['roi2']=='iCAP_C5toC7_VL')]['rho_Z'].values]
dd = [corrs_df[(corrs_df['sess']=='T3') & (corrs_df['roi1']=='iCAP_C5toC7_DR') & (corrs_df['roi2']=='iCAP_C5toC7_DL')]['rho_Z'].values]
dv_r = [corrs_df[(corrs_df['sess']=='T3') & (corrs_df['roi1']=='iCAP_C5toC7_VR') & (corrs_df['roi2']=='iCAP_C5toC7_DR')]['rho_Z'].values]    
dv_l = [corrs_df[(corrs_df['sess']=='T3') & (corrs_df['roi1']=='iCAP_C5toC7_VL') & (corrs_df['roi2']=='iCAP_C5toC7_DL')]['rho_Z'].values]   
vr_dl = [corrs_df[(corrs_df['sess']=='T3') & (corrs_df['roi1']=='iCAP_C5toC7_VR') & (corrs_df['roi2']=='iCAP_C5toC7_DL')]['rho_Z'].values]    
vl_dr = [corrs_df[(corrs_df['sess']=='T3') & (corrs_df['roi1']=='iCAP_C5toC7_VL') & (corrs_df['roi2']=='iCAP_C5toC7_DR')]['rho_Z'].values]    
# For all
#corrs_totest = np.transpose(np.concatenate((vv,dd,dv_r,dv_l,vr_dl,vl_dr),axis=0))
#corrs_totest_names = ['V-V','D-D','D-V (R)', 'D-V (L)', 'VR-DL', 'VL-DR']

# Just for DD VV
corrs_totest = np.transpose(np.concatenate((vv,dd),axis=0))
corrs_totest_names = ['V-V','D-D']

# %%
dd = [corrs_df[(corrs_df['sess']=='T3') & (corrs_df['roi1']=='frost_C5toC7_DR') & (corrs_df['roi2']=='frost_C5toC7_DL')]['rho_Z'].values]
# For all
#corrs_totest = np.transpose(np.concatenate((vv,dd,dv_r,dv_l,vr_dl,vl_dr),axis=0))
#corrs_totest_names = ['V-V','D-D','D-V (R)', 'D-V (L)', 'VR-DL', 'VL-DR']

# Just for DD VV
corrs_totest = np.transpose(np.concatenate((vv,dd),axis=0))
corrs_totest_names = ['V-V','D-D']

# %% [markdown]
# _**If using all individual spinal levels**_

# %%
c5_vv = [corrs_df[(corrs_df['roi1']=='C5_VR') & (corrs_df['roi2']=='C5_VL')]['rho_Z'].values]
c5_dd = [corrs_df[(corrs_df['roi1']=='C5_DR') & (corrs_df['roi2']=='C5_DL')]['rho_Z'].values]
c6_vv = [corrs_df[(corrs_df['roi1']=='C6_VR') & (corrs_df['roi2']=='C6_VL')]['rho_Z'].values]
c6_dd = [corrs_df[(corrs_df['roi1']=='C6_DR') & (corrs_df['roi2']=='C6_DL')]['rho_Z'].values]
c7_vv = [corrs_df[(corrs_df['roi1']=='C7_VR') & (corrs_df['roi2']=='C7_VL')]['rho_Z'].values]
c7_dd = [corrs_df[(corrs_df['roi1']=='C7_DR') & (corrs_df['roi2']=='C7_DL')]['rho_Z'].values]
corrs_totest = np.transpose(np.concatenate((c5_vv,c5_dd,c6_vv,c6_dd,c7_vv,c7_dd),axis=0))
corrs_totest_names = ['C5 V-V','C5 D-D','C6 V-V','C6 D-D','C7 V-V','C7 D-D']

# %% [markdown]
# #### Option 2: Significant FC

# %% [markdown]
# _Note: there were 3 significant correlations: **(1)** C5DR-C5VR, **(2)** C6DL-C6DR, **(3)** C6DR-C6VR_

# %%
C5DR_C5VR = [corrs_df[(corrs_df['sess']=='T3') & (corrs_df['roi1']=='C5_DR') & (corrs_df['roi2']=='C5_VR')]['rho_Z'].values]
C6DL_C6DR  = [corrs_df[(corrs_df['sess']=='T3') & (corrs_df['roi1']=='C6_DL') & (corrs_df['roi2']=='C6_DR')]['rho_Z'].values]
C6DR_C6VR = [corrs_df[(corrs_df['sess']=='T3') & (corrs_df['roi1']=='C6_DR') & (corrs_df['roi2']=='C6_VR')]['rho_Z'].values]
corrs_totest = np.transpose(np.concatenate((C5DR_C5VR,C6DL_C6DR,C6DR_C6VR),axis=0))
corrs_totest_names = ['C5DR-C5VR','C6DL-C6DR','C6DR-C6VR']

# %% [markdown]
# #### ! To run for all options

# %%
patients.compute_correlations(clinical_data=clinical_info,clinical_names=['fm','mas','pinch','CST','vol'],totest_values=corrs_totest,totest_names=corrs_totest_names)
# Out:
#   tested clinical       rho         p
# 0    V-V       fm -0.156250  0.627723
# 1    D-D       fm  0.157581  0.624759
# 2    V-V      mas -0.024956  0.938635
# 3    D-D      mas -0.116896  0.717503
# 4    V-V    pinch -0.125746  0.696980
# 5    D-D    pinch  0.293018  0.355330
# 6    V-V      CST  0.154083  0.632562
# 7    D-D      CST -0.015691  0.961399
# 8    V-V      vol  0.034754  0.914611
# 9    D-D      vol -0.156042  0.628188

# %%
frames_df = pd.read_csv('/media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/iCAPs_results/PAM50_C5toC7_14P_Alpha_5_95_Fraction_0DOT05/K_30_Dist_cosine_Folds_20/Frames.csv',header=None, names=['iCAP1','iCAP2','iCAP3','iCAP4','iCAP5','iCAP6','iCAP7','iCAP8','iCAP9','iCAP10','iCAP11','iCAP12','iCAP13','iCAP14','iCAP15','iCAP16','iCAP17','iCAP18','iCAP19','iCAP20','iCAP21','iCAP22','iCAP23','iCAP24','iCAP25','iCAP26','iCAP27','iCAP28','iCAP29','iCAP30'])

# %%
frames = np.loadtxt('/media/miplab-nas2/Data3/SpinalCord/4_Age_Stroke/iCAPs_results/PAM50_C5toC7_14P_Alpha_5_95_Fraction_0DOT05/K_30_Dist_cosine_Folds_20/Frames.csv',delimiter=",")

# %%
frames[:,[3,6,16,21]]
# Out:
# array([[14., 11., 13., 10.],
#        [17., 21., 16., 14.],
#        [10., 11., 11.,  5.],
#        [18., 19., 18., 10.],
#        [27., 17.,  9.,  9.],
#        [ 9., 14., 16.,  6.],
#        [29., 22., 13.,  8.],
#        [23., 13., 12., 10.],
#        [17., 17., 12., 14.],
#        [20., 11., 11.,  6.],
#        [16., 24., 14., 19.],
#        [15., 20., 13.,  6.],
#        [18., 13.,  6., 18.],
#        [11.,  8., 14., 15.]])

# %%
t=clinical_correlations['p']<0.01
[i for i, x in enumerate(t) if x]
# Out:
# [130]

# %%
clinical_correlations=patients.compute_correlations(clinical_data=clinical_info,clinical_names=['CST','vol'],totest_values=frames[:,[3,6,16,21]],totest_names=['iCAP3','iCAP6','iCAP16','iCAP21'])

# %%
clinical_correlations
# Out:
#    tested clinical       rho         p
# 0   iCAP3      CST -0.295225  0.351547
# 1   iCAP6      CST  0.332495  0.290981
# 2  iCAP16      CST  0.594227  0.041598
# 3  iCAP21      CST -0.205937  0.520788
# 4   iCAP3      vol  0.012047  0.970358
# 5   iCAP6      vol -0.116399  0.718662
# 6  iCAP16      vol -0.677699  0.015448
# 7  iCAP21      vol  0.460771  0.131674

# %%
clinical_correlations=patients.compute_correlations(clinical_data=clinical_info,clinical_names=['fm','mas','pinch','CST','vol'],totest_values=frames,totest_names=['iCAP1','iCAP2','iCAP3','iCAP4','iCAP5','iCAP6','iCAP7','iCAP8','iCAP9','iCAP10','iCAP11','iCAP12','iCAP13','iCAP14','iCAP15','iCAP16','iCAP17','iCAP18','iCAP19','iCAP20','iCAP21','iCAP22','iCAP23','iCAP24','iCAP25','iCAP26','iCAP27','iCAP28','iCAP29','iCAP30'])

# %% [markdown]
# #### Test with classification

# %%
# Extract corr for controls (already done above for patients)
vv = [corrs_df[(corrs_df['sess']=='') & (corrs_df['roi1']=='mask_midC5toC7_gm_VR') & (corrs_df['roi2']=='mask_midC5toC7_gm_VL')]['rho_Z'].values]
dd = [corrs_df[(corrs_df['sess']=='') & (corrs_df['roi1']=='mask_midC5toC7_gm_DR') & (corrs_df['roi2']=='mask_midC5toC7_gm_DL')]['rho_Z'].values]
dv_r = [corrs_df[(corrs_df['sess']=='') & (corrs_df['roi1']=='mask_midC5toC7_gm_VR') & (corrs_df['roi2']=='mask_midC5toC7_gm_DR')]['rho_Z'].values]    
dv_l = [corrs_df[(corrs_df['sess']=='') & (corrs_df['roi1']=='mask_midC5toC7_gm_VL') & (corrs_df['roi2']=='mask_midC5toC7_gm_DL')]['rho_Z'].values]   
vr_dl = [corrs_df[(corrs_df['sess']=='') & (corrs_df['roi1']=='mask_midC5toC7_gm_VR') & (corrs_df['roi2']=='mask_midC5toC7_gm_DL')]['rho_Z'].values]    
vl_dr = [corrs_df[(corrs_df['sess']=='') & (corrs_df['roi1']=='mask_midC5toC7_gm_VL') & (corrs_df['roi2']=='mask_midC5toC7_gm_DR')]['rho_Z'].values]    
corrs_totest_H = np.transpose(np.concatenate((vv,dd,dv_r,dv_l,vr_dl,vl_dr),axis=0))

# %%
# Create dataframe
corrs_totest_P_withgrp = np.hstack((corrs_totest_P, 2*np.ones((corrs_totest_P.shape[0], 1))))
corrs_totest_H_withgrp = np.hstack((corrs_totest_H, np.ones((corrs_totest_H.shape[0], 1))))
data_classif = np.concatenate([corrs_totest_P_withgrp, corrs_totest_H_withgrp],axis=0)
col_names = ['V-V','D-D','D-V (R)', 'D-V (L)', 'VR-DL', 'VL-DR', 'grp']
data_classif_df = pd.DataFrame(data=data_classif, columns=col_names)

# %%
data_classif_df['grp'] = data_classif_df['grp'].astype('int')

# %%
X = data_classif_df[col_names[:-1]]
y = data_classif_df[col_names[-1]]

# %%
# Feature Scaling 
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler() 
X = sc.fit_transform(X)

# %%
# Fitting Kernel SVM to the Training set 
from sklearn.svm import SVC 
classifier = SVC(kernel = 'rbf', random_state = 0) 
classifier.fit(X, y)
# Out:
# SVC(random_state=0)

# %%
# Applying k-Fold Cross Validation 
from sklearn.model_selection import cross_val_score 
accuracies = cross_val_score(estimator = classifier, X = X, y = y, cv = 8) 
accuracies.mean() 
accuracies.std()
# Out:
# 0.0721687836487032

# %% [markdown]
# #### 3. ALFF analyses

# %%
sFC.compute_alff_maps()

# %%
sFC.compute_alff_rois()
# Out:
# ALFF IN ROIS
# Overwrite old files: True
# Extracting ALFF for subject SUVA-TIMES-002
# ...Session T3
# 231030-12:50:49,469 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:49.469189:1.614804
# 231030-12:50:50,196 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:50.195906:1.572717
# 231030-12:50:50,870 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:50.870116:1.467526
# 231030-12:50:51,609 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:51.609673:1.463413
# Extracting ALFF for subject SUVA-TIMES-003
# ...Session T3
# 231030-12:50:52,375 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:52.375527:1.939050
# 231030-12:50:53,33 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:53.033057:1.968394
# 231030-12:50:53,664 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:53.664006:2.088278
# 231030-12:50:54,328 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:54.328730:2.076734
# Extracting ALFF for subject SUVA-TIMES-006
# ...Session T3
# 231030-12:50:55,67 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:55.067707:1.799177
# 231030-12:50:55,764 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:55.764174:1.869052
# 231030-12:50:56,404 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:56.404014:1.741186
# 231030-12:50:57,41 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:57.040787:1.684316
# Extracting ALFF for subject SUVA-TIMES-007
# ...Session T3
# 231030-12:50:57,834 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:57.833827:1.728023
# 231030-12:50:58,467 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:58.466939:1.587655
# 231030-12:50:59,116 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:59.116143:1.701232
# 231030-12:50:59,805 nipype.interface INFO:
# 	 stdout 2023-10-30T12:50:59.804908:1.611221
# Extracting ALFF for subject SUVA-TIMES-008
# ...Session T3
# 231030-12:51:00,562 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:00.562754:1.873238
# 231030-12:51:01,184 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:01.184609:1.859090
# 231030-12:51:01,788 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:01.788699:1.925551
# 231030-12:51:02,361 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:02.360863:1.986375
# Extracting ALFF for subject SUVA-TIMES-010
# ...Session T3
# 231030-12:51:03,159 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:03.159494:1.562919
# 231030-12:51:03,810 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:03.810183:1.512027
# 231030-12:51:04,401 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:04.400998:1.712045
# 231030-12:51:04,989 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:04.989698:1.647969
# Extracting ALFF for subject SUVA-TIMES-014
# ...Session T3
# 231030-12:51:05,658 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:05.658358:2.129830
# 231030-12:51:06,267 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:06.266757:2.040994
# 231030-12:51:06,903 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:06.903317:2.146345
# 231030-12:51:07,490 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:07.490321:2.145628
# Extracting ALFF for subject SUVA-TIMES-021
# ...Session T3
# 231030-12:51:08,309 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:08.308890:1.619851
# 231030-12:51:08,923 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:08.923661:1.652483
# 231030-12:51:09,503 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:09.503013:1.834520
# 231030-12:51:10,144 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:10.144439:1.806224
# Extracting ALFF for subject SUVA-TIMES-022
# ...Session T3
# 231030-12:51:11,27 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:11.027041:1.500941
# 231030-12:51:11,671 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:11.670869:1.463570
# 231030-12:51:12,309 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:12.309324:1.547682
# 231030-12:51:12,955 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:12.955451:1.553254
# Extracting ALFF for subject SUVA-TIMES-023
# ...Session T3
# 231030-12:51:13,704 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:13.703858:1.653539
# 231030-12:51:14,347 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:14.347190:1.736040
# 231030-12:51:14,999 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:14.998991:1.669284
# 231030-12:51:15,678 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:15.678068:1.815762
# Extracting ALFF for subject SUVA-TIMES-025
# ...Session T3
# 231030-12:51:16,403 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:16.403385:1.845076
# 231030-12:51:17,64 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:17.063812:2.015162
# 231030-12:51:17,693 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:17.692970:1.928843
# 231030-12:51:18,329 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:18.329345:2.030190
# Extracting ALFF for subject SUVA-TIMES-026
# ...Session T3
# 231030-12:51:19,59 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:19.059644:1.955576
# 231030-12:51:19,668 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:19.667865:2.124415
# 231030-12:51:20,251 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:20.251512:1.921363
# 231030-12:51:20,832 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:20.832023:2.114184
# Extracting ALFF for subject SUVA-TIMES-028
# ...Session T3
# 231030-12:51:21,445 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:21.445377:1.635636
# 231030-12:51:22,51 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:22.051013:1.488497
# 231030-12:51:22,707 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:22.707035:1.514529
# 231030-12:51:23,331 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:23.331290:1.491278
# Extracting ALFF for subject SUVA-TIMES-031
# ...Session T3
# 231030-12:51:24,109 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:24.109585:1.515149
# 231030-12:51:24,733 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:24.733523:1.556957
# 231030-12:51:25,352 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:25.352217:1.760509
# 231030-12:51:25,972 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:25.972642:1.705980
# Extracting ALFF for subject sub-001
# ...Session
# 231030-12:51:26,648 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:26.648171:1.607699
# 231030-12:51:27,307 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:27.307325:1.501367
# 231030-12:51:27,947 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:27.947179:1.615310
# 231030-12:51:28,569 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:28.569196:1.560879
# Extracting ALFF for subject sub-002
# ...Session
# 231030-12:51:29,280 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:29.280501:1.365865
# 231030-12:51:29,899 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:29.899484:1.385959
# 231030-12:51:30,538 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:30.538359:1.421622
# 231030-12:51:31,162 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:31.161772:1.464237
# Extracting ALFF for subject sub-004
# ...Session
# 231030-12:51:31,863 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:31.863550:1.436099
# 231030-12:51:32,487 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:32.486939:1.608241
# 231030-12:51:33,119 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:33.119005:1.659215
# 231030-12:51:33,729 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:33.728901:1.625980
# Extracting ALFF for subject sub-005
# ...Session
# 231030-12:51:34,358 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:34.358528:1.495359
# 231030-12:51:34,986 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:34.986712:1.465534
# 231030-12:51:35,619 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:35.618806:1.415828
# 231030-12:51:36,213 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:36.212831:1.501766
# Extracting ALFF for subject sub-007
# ...Session
# 231030-12:51:36,895 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:36.895422:1.410802
# 231030-12:51:37,528 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:37.527911:1.418832
# 231030-12:51:38,155 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:38.155630:1.437498
# 231030-12:51:38,771 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:38.771214:1.445034
# Extracting ALFF for subject sub-009
# ...Session
# 231030-12:51:39,446 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:39.446575:1.552787
# 231030-12:51:40,51 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:40.050774:1.573236
# 231030-12:51:40,653 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:40.653090:1.513601
# 231030-12:51:41,254 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:41.254447:1.513265
# Extracting ALFF for subject sub-011
# ...Session
# 231030-12:51:42,154 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:42.153950:1.644519
# 231030-12:51:42,790 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:42.790703:1.700908
# 231030-12:51:43,404 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:43.403935:1.873325
# 231030-12:51:44,28 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:44.028693:1.821702
# Extracting ALFF for subject sub-012
# ...Session
# 231030-12:51:44,633 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:44.633151:1.461947
# 231030-12:51:45,269 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:45.269293:1.752586
# 231030-12:51:45,876 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:45.875901:1.829699
# 231030-12:51:46,503 nipype.interface INFO:
# 	 stdout 2023-10-30T12:51:46.503016:2.140258
#                sub sess             roi      alff
# 0   SUVA-TIMES-002   T3  iCAP_C5toC7_VL  1.614804
# 1   SUVA-TIMES-002   T3  iCAP_C5toC7_VR  1.572717
# 2   SUVA-TIMES-002   T3  iCAP_C5toC7_DL  1.467526
# 3   SUVA-TIMES-002   T3  iCAP_C5toC7_DR  1.463413
# 4   SUVA-TIMES-003   T3  iCAP_C5toC7_VL  1.939050
# ..             ...  ...             ...       ...
# 83         sub-011       iCAP_C5toC7_DR  1.821702
# 84         sub-012       iCAP_C5toC7_VL  1.461947
# 85         sub-012       iCAP_C5toC7_VR  1.752586
# 86         sub-012       iCAP_C5toC7_DL  1.829699
# 87         sub-012       iCAP_C5toC7_DR  2.140258
#
# [88 rows x 4 columns]
